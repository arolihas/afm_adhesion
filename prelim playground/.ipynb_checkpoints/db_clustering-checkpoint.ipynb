# %%
import pandas
from os import listdir, getcwd
from os.path import isfile, join

# %%
path = getcwd()
files = [f for f in listdir(path) if isfile(join(path, f)) and '.csv' in f]
files
# Out:
# ['MLCT_B_20D_00A_S10006_0.0075.csv',
#  'ar500p_E3_S1_003_0.072.csv',
#  'a200pr20nE8S20005_Apr_0.118.csv',
#  'a200pr20nE1S20003_Apr_0.118.csv',
#  'ar20005_0.0248.csv',
#  'iD4_S1_0VacBD0004_Apr_0.089.csv']

# %%
data_list = {}
for f in files:
    data_list[f] = pandas.read_csv(f)

# %%
for f in files:
    print(data_list[f].columns)
# Out:
# Index(['ZIndex', ' No', 'zSensr', 'defl'], dtype='object')
# Index(['No', 'defl', 'zSensr'], dtype='object')
# Index(['No', 'zSensr', 'defl'], dtype='object')
# Index(['No', 'zSensr', 'defl'], dtype='object')
# Index(['No', 'defl', 'zSensr'], dtype='object')
# Index(['No', 'defl', 'zSensr'], dtype='object')

# %%
data_list[files[0]] = data_list[files[0]].drop([' No'], axis=1)

# %%
data_list[files[0]] = data_list[files[0]].rename(columns={'ZIndex':'No'})
for f in files:
    data_list[f] = data_list[f].reindex(columns=['No','zSensr','defl'])

# %%
approach_curve = []
approach_constants = []
full_curve = []
full_constants = []
for k in data_list:
    if 'Apr' in k:
        approach_curve.append(data_list[k])
        approach_constants.append(float(k[-9:-4]))
    else:
        full_curve.append(data_list[k])
        full_constants.append(float(k[-9:-4]))
for i in range(len(approach_curve)):
    approach_curve[i].defl *= approach_constants[i]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# **Approach Curve 0**

# %%
matplotlib.rcParams['agg.path.chunksize'] = 10000
n = 0
d = approach_curve[n].defl * approach_constants[n]
z = approach_curve[n].zSensr
t = approach_curve[n].No

plt.figure(figsize=(9, 8))
plt.suptitle('Approach Curve ' + str(n))
plt.subplot(211)
plt.plot(t, d)
plt.ylabel('Force (N)')
plt.subplot(212)
plt.plot(t, z)
plt.ylabel('Z position')
# Out:
# Text(0, 0.5, 'Z position')

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN, OPTICS
import numpy as np
 sklean.utils

# %%
X = pandas.concat([d,z], axis=1).values
scaler = StandardScaler()  
scaler.fit_transform(X)
# Out:
# array([[ 0.7540635 , -3.10152394],
#        [ 0.48408443, -3.07480408],
#        [ 0.05076764, -3.01924373],
#        ...,
#        [ 2.42455578,  3.35217079],
#        [ 2.35166937,  3.39055408],
#        [ 2.3311231 ,  3.40200545]])

# %%
opt = OPTICS(min_samples=100000)
labels = opt.fit_predict(X)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-15-14d7311e7b50>", line 2, in <module>
#     labels = opt.fit_predict(X)
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/sklearn/base.py", line 447, in fit_predict
#     self.fit(X)
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/sklearn/cluster/optics_.py", line 248, in fit
#     max_eps=self.max_eps)
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/sklearn/cluster/optics_.py", line 462, in compute_optics_graph
#     working_memory=None)
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/sklearn/cluster/optics_.py", line 327, in _compute_core_distances_
#     X[sl], min_samples)[0][:, -1]
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/base.py", line 454, in kneighbors
#     for s in gen_even_slices(X.shape[0], n_jobs)
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/joblib/parallel.py", line 921, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 549, in __init__
#     self.results = batch()
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/joblib/parallel.py", line 225, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/joblib/parallel.py", line 225, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/base.py", line 291, in _tree_query_parallel_helper
#     return tree.query(data, n_neighbors, return_distance)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2039, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/home/sahil/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/sahil/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/sahil/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/sahil/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/sahil/anaconda3/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
dbs = DBSCAN()
dbs.fit(X)

# %%
neigh = NearestNeighbors(n_neighbors=50000)
nbrs = neigh.fit(X)
distances = nbrs.kneighbors(X)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-16-e9280f985223> in <module>()
#       1 neigh = NearestNeighbors(n_neighbors=50000)
#       2 nbrs = neigh.fit(X)
# ----> 3 distances = nbrs.kneighbors(X)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/neighbors/base.py in kneighbors(self, X, n_neighbors, return_distance)
#     441                 delayed_query(
#     442                     X[s], n_neighbors, return_distance)
# --> 443                 for s in gen_even_slices(X.shape[0], n_jobs)
#     444             )
#     445         else:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     981             # remaining jobs.
#     982             self._iterating = False
# --> 983             if self.dispatch_one_batch(iterator):
#     984                 self._iterating = self._original_iterator is not None
#     985
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     823                 return False
#     824             else:
# --> 825                 self._dispatch(tasks)
#     826                 return True
#     827
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     543         # Don't delay the application, to avoid keeping the input
#     544         # arguments in memory
# --> 545         self.results = batch()
#     546
#     547     def get(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# sklearn/neighbors/binary_tree.pxi in sklearn.neighbors.kd_tree.BinaryTree.query()
#
# sklearn/neighbors/binary_tree.pxi in sklearn.neighbors.kd_tree.NeighborsHeap.__init__()
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in full(shape, fill_value, dtype, order)
#     330     if dtype is None:
#     331         dtype = array(fill_value).dtype
# --> 332     a = empty(shape, dtype, order)
#     333     multiarray.copyto(a, fill_value, casting='unsafe')
#     334     return a
#
# MemoryError: Unable to allocate array with shape (943446, 50000) and data type float64

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %% [markdown]
# **Approach Curve 1**

# %%
matplotlib.rcParams['agg.path.chunksize'] = 10000
n = 1
d = approach_curve[n].defl * approach_constants[n]
z = approach_curve[n].zSensr
t = approach_curve[n].No

plt.figure(figsize=(9, 8))
plt.suptitle('Approach Curve ' + str(n))
plt.subplot(211)
plt.plot(t, d)
plt.ylabel('Force (N)')
plt.subplot(212)
plt.plot(t, z)
plt.ylabel('Z position')
# Out:
# Text(0,0.5,'Z position')

# %%
X = pandas.concat([d,z], axis=1).values
scaler = StandardScaler()  
scaler.fit_transform(X)

# %%
db = DBSCAN()
db.fit(X)

# %%
plt.figure(figsize=(9, 8))
plt.suptitle('Approach Curve ' + str(n))
plt.subplot(211)
plt.scatter(t, d, c=db.labels_)
plt.ylabel('Force (N)')
plt.subplot(212)
plt.plot(t, z, c=db.labels_)
plt.ylabel('Z position')

# %%
neigh = NearestNeighbors(n_neighbors=50000)
nbrs = neigh.fit(X)
distances = nbrs.kneighbors(X)

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %% [markdown]
# **Approach Curve 2**

# %%
matplotlib.rcParams['agg.path.chunksize'] = 10000
n = 2
d = approach_curve[n].defl * approach_constants[n]
z = approach_curve[n].zSensr
t = approach_curve[n].No

plt.figure(figsize=(9, 8))
plt.suptitle('Approach Curve ' + str(n))
plt.subplot(211)
plt.plot(t, d)
plt.ylabel('Force (N)')
plt.subplot(212)
plt.plot(t, z)
plt.ylabel('Z position')
# Out:
# Text(0,0.5,'Z position')

# %%
X = pandas.concat([d,z], axis=1).values
scaler = StandardScaler()  
scaler.fit_transform(X)
# Out:
# array([[ 0.55839449,  1.73205252],
#        [ 0.47466945,  1.73205252],
#        [ 0.56564211,  1.73205252],
#        ...,
#        [ 1.24446561, -1.73204519],
#        [ 1.29970783, -1.73204519],
#        [ 1.30774855, -1.73205256]])

# %%
db = DBSCAN()
db.fit(X)

# %%
plt.figure(figsize=(9, 8))
plt.suptitle('Approach Curve ' + str(n))
plt.subplot(211)
plt.scatter(t, d, c=db.labels_)
plt.ylabel('Force (N)')
plt.subplot(212)
plt.plot(t, z, c=db.labels_)
plt.ylabel('Z position')

# %%
neigh = NearestNeighbors(n_neighbors=50000)
nbrs = neigh.fit(X)
distances = nbrs.kneighbors(X)

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)
